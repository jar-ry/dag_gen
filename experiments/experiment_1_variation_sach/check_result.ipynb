# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('experiment_1_result.csv')

# %%
df
# Out:
#     Unnamed: 0       fdr       tpr       fpr  shd  false_pos  false_neg  \
# 0            0  0.200000  0.125000  0.076923   28          0         27
# 1            0  0.375000  0.312500  0.461538   27          5         21
# 2            0  0.869565  0.093750  1.538462   38          7         19
# 3            0  0.644444  1.000000  4.461538   45         26          0
# 4            0  0.285714  0.178571  0.117647   24          1         22
# 5            0  1.000000  0.000000  0.470588   31          3         23
# 6            0  0.818182  0.071429  0.529412   31          5         23
# 7            0  0.803030  0.928571  2.789474   91         81         14
# 8            0  0.375000  0.172414  0.187500   25          1         22
# 9            0  0.333333  0.068966  0.062500   28          1         27
# 10           0  0.333333  0.068966  0.062500   28          1         27
# 11           0  0.677778  1.000000  3.812500   45         32          0
# 12           0  0.428571  0.133333  0.200000   27          1         24
# 13           0  0.500000  0.033333  0.066667   30          1         29
# 14           0  0.857143  0.033333  0.400000   32          3         26
# 15           0  0.666667  1.000000  4.000000   45         30          0
# 16           0  0.375000  0.138889  0.333333   33          2         30
# 17           0  0.800000  0.027778  0.444444   36          1         32
# 18           0  1.000000  0.000000  0.666667   36          0         30
# 19           0  0.600000  1.000000  6.000000   45         18          0
# 20           0  0.333333  0.111111  0.222222   32          0         30
# 21           0  1.000000  0.000000  0.222222   36          0         34
# 22           0  0.666667  0.027778  0.222222   36          1         34
# 23           0  0.600000  1.000000  6.000000   45         18          0
# 24           0  0.333333  0.516129  0.571429   20          5         12
# 25           0  0.500000  0.161290  0.357143   27          1         22
# 26           0  0.583333  0.161290  0.500000   30          1         23
# 27           0  0.655556  1.000000  4.214286   45         28          0
# 28           0  0.200000  0.250000  0.153846   24          0         22
# 29           0  0.230769  0.312500  0.230769   24          2         21
# 30           0  0.818182  0.125000  1.384615   36          6         20
# 31           0  0.644444  1.000000  4.461538   45         26          0
# 32           0  0.300000  0.225806  0.214286   24          0         21
# 33           0  0.800000  0.032258  0.285714   31          1         27
# 34           0  0.666667  0.032258  0.142857   31          1         29
# 35           0  0.655556  1.000000  4.214286   45         28          0
#
#     reserved_edges  pred_size  true_size       timing    causal_mech  \
# 0                1          5         32     2.479280  mix_mechanism
# 1                1         16         32  3662.652781  mix_mechanism
# 2               13         23         32  7069.577734  mix_mechanism
# 3               32         90         32    10.191270  mix_mechanism
# 4                1          7         28     2.496820  mix_mechanism
# 5                5          8         28  3680.601102  mix_mechanism
# 6                4         11         28  7053.183498  mix_mechanism
# 7               25        132         28    11.183953  mix_mechanism
# 8                2          8         29     2.446275  mix_mechanism
# 9                0          3         29  4100.530586  mix_mechanism
# 10               0          3         29  7097.069032  mix_mechanism
# 11              29         90         29    10.198105  mix_mechanism
# 12               2          7         30     2.448093  mix_mechanism
# 13               0          2         30  3879.239622  mix_mechanism
# 14               3          7         30  7036.396723  mix_mechanism
# 15              30         90         30     9.938458  mix_mechanism
# 16               1          8         36     2.456766  mix_mechanism
# 17               3          5         36  4431.831666  mix_mechanism
# 18               6          6         36  7045.255642  mix_mechanism
# 19              36         90         36    10.004707  mix_mechanism
# 20               2          6         36     2.478568  mix_mechanism
# 21               2          2         36  4631.625918  mix_mechanism
# 22               1          3         36  7097.598847  mix_mechanism
# 23              36         90         36    10.221597  mix_mechanism
# 24               3         24         31     2.465978  mix_mechanism
# 25               4         10         31  3920.717484  mix_mechanism
# 26               6         12         31  7100.227097  mix_mechanism
# 27              31         90         31    10.162787  mix_mechanism
# 28               2         10         32     2.849715  mix_mechanism
# 29               1         13         32  5167.221041  mix_mechanism
# 30              12         22         32  7871.358481  mix_mechanism
# 31              32         90         32    10.130381  mix_mechanism
# 32               3         10         31     2.566578  mix_mechanism
# 33               3          5         31  4060.687851  mix_mechanism
# 34               1          3         31  7140.358513  mix_mechanism
# 35              31         90         31    10.195271  mix_mechanism
#
#                        dataset              dataset_name  dataset_index  \
# 0      medium_no_issue_noise_3     medium_no_issue_noise              3
# 1      medium_no_issue_noise_3     medium_no_issue_noise              3
# 2      medium_no_issue_noise_3     medium_no_issue_noise              3
# 3      medium_no_issue_noise_3     medium_no_issue_noise              3
# 4                 medium_all_3                medium_all              3
# 5                 medium_all_3                medium_all              3
# 6                 medium_all_3                medium_all              3
# 7                 medium_all_3                medium_all              3
# 8                 medium_all_2                medium_all              2
# 9                 medium_all_2                medium_all              2
# 10                medium_all_2                medium_all              2
# 11                medium_all_2                medium_all              2
# 12                medium_all_1                medium_all              1
# 13                medium_all_1                medium_all              1
# 14                medium_all_1                medium_all              1
# 15                medium_all_1                medium_all              1
# 16  medium_no_issue_no_noise_1  medium_no_issue_no_noise              1
# 17  medium_no_issue_no_noise_1  medium_no_issue_no_noise              1
# 18  medium_no_issue_no_noise_1  medium_no_issue_no_noise              1
# 19  medium_no_issue_no_noise_1  medium_no_issue_no_noise              1
# 20     medium_no_issue_noise_1     medium_no_issue_noise              1
# 21     medium_no_issue_noise_1     medium_no_issue_noise              1
# 22     medium_no_issue_noise_1     medium_no_issue_noise              1
# 23     medium_no_issue_noise_1     medium_no_issue_noise              1
# 24  medium_no_issue_no_noise_2  medium_no_issue_no_noise              2
# 25  medium_no_issue_no_noise_2  medium_no_issue_no_noise              2
# 26  medium_no_issue_no_noise_2  medium_no_issue_no_noise              2
# 27  medium_no_issue_no_noise_2  medium_no_issue_no_noise              2
# 28  medium_no_issue_no_noise_3  medium_no_issue_no_noise              3
# 29  medium_no_issue_no_noise_3  medium_no_issue_no_noise              3
# 30  medium_no_issue_no_noise_3  medium_no_issue_no_noise              3
# 31  medium_no_issue_no_noise_3  medium_no_issue_no_noise              3
# 32     medium_no_issue_noise_2     medium_no_issue_noise              2
# 33     medium_no_issue_noise_2     medium_no_issue_noise              2
# 34     medium_no_issue_noise_2     medium_no_issue_noise              2
# 35     medium_no_issue_noise_2     medium_no_issue_noise              2
#
#         algo
# 0   gran_dag
# 1    dag_gnn
# 2     rl_bic
# 3        sam
# 4   gran_dag
# 5    dag_gnn
# 6     rl_bic
# 7        sam
# 8   gran_dag
# 9    dag_gnn
# 10    rl_bic
# 11       sam
# 12  gran_dag
# 13   dag_gnn
# 14    rl_bic
# 15       sam
# 16  gran_dag
# 17   dag_gnn
# 18    rl_bic
# 19       sam
# 20  gran_dag
# 21   dag_gnn
# 22    rl_bic
# 23       sam
# 24  gran_dag
# 25   dag_gnn
# 26    rl_bic
# 27       sam
# 28  gran_dag
# 29   dag_gnn
# 30    rl_bic
# 31       sam
# 32  gran_dag
# 33   dag_gnn
# 34    rl_bic
# 35       sam

# %%
grouped_df = df.groupby(by=['dataset_name', 'algo']).aggregate('mean').reset_index()
grouped_df
# Out:
#                 dataset_name      algo  Unnamed: 0       fdr       tpr  \
# 0                 medium_all   dag_gnn         0.0  0.611111  0.034100
# 1                 medium_all  gran_dag         0.0  0.363095  0.161440
# 2                 medium_all    rl_bic         0.0  0.669553  0.057909
# 3                 medium_all       sam         0.0  0.715825  0.976190
# 4   medium_no_issue_no_noise   dag_gnn         0.0  0.510256  0.167189
# 5   medium_no_issue_no_noise  gran_dag         0.0  0.302778  0.301673
# 6   medium_no_issue_no_noise    rl_bic         0.0  0.800505  0.095430
# 7   medium_no_issue_no_noise       sam         0.0  0.633333  1.000000
# 8      medium_no_issue_noise   dag_gnn         0.0  0.725000  0.114919
# 9      medium_no_issue_noise  gran_dag         0.0  0.277778  0.153973
# 10     medium_no_issue_noise    rl_bic         0.0  0.734300  0.051262
# 11     medium_no_issue_noise       sam         0.0  0.633333  1.000000
#
#          fpr        shd  false_pos  false_neg  reserved_edges   pred_size  \
# 0   0.199918  29.666667   1.666667  26.333333        1.666667    4.333333
# 1   0.168382  25.333333   1.000000  22.666667        1.666667    7.333333
# 2   0.330637  30.333333   3.000000  25.333333        2.333333    7.000000
# 3   3.533991  60.333333  47.666667   4.666667       28.000000  104.000000
# 4   0.344119  29.000000   1.333333  25.000000        2.666667    9.333333
# 5   0.352869  25.666667   2.333333  21.333333        2.000000   14.000000
# 6   0.850427  34.000000   2.333333  24.333333        8.000000   13.333333
# 7   4.891941  45.000000  24.000000   0.000000       33.000000   90.000000
# 8   0.323158  31.333333   2.000000  27.333333        2.000000    7.666667
# 9   0.171144  28.000000   0.000000  26.000000        2.000000    7.000000
# 10  0.634514  35.000000   3.000000  27.333333        5.000000    9.666667
# 11  4.891941  45.000000  24.000000   0.000000       33.000000   90.000000
#
#     true_size       timing  dataset_index
# 0        29.0  3886.790437            2.0
# 1        29.0     2.463730            2.0
# 2        29.0  7062.216417            2.0
# 3        29.0    10.440172            2.0
# 4        33.0  4506.590064            2.0
# 5        33.0     2.590820            2.0
# 6        33.0  7338.947073            2.0
# 7        33.0    10.099292            2.0
# 8        33.0  4118.322184            2.0
# 9        33.0     2.508142            2.0
# 10       33.0  7102.511698            2.0
# 11       33.0    10.202713            2.0

# %%
grouped_df[grouped_df['dataset_name']=='medium_all']
# Out:
#   dataset_name      algo  Unnamed: 0       fdr       tpr       fpr        shd  \
# 0   medium_all   dag_gnn         0.0  0.611111  0.034100  0.199918  29.666667
# 1   medium_all  gran_dag         0.0  0.363095  0.161440  0.168382  25.333333
# 2   medium_all    rl_bic         0.0  0.669553  0.057909  0.330637  30.333333
# 3   medium_all       sam         0.0  0.715825  0.976190  3.533991  60.333333
#
#    false_pos  false_neg  reserved_edges   pred_size  true_size       timing  \
# 0   1.666667  26.333333        1.666667    4.333333       29.0  3886.790437
# 1   1.000000  22.666667        1.666667    7.333333       29.0     2.463730
# 2   3.000000  25.333333        2.333333    7.000000       29.0  7062.216417
# 3  47.666667   4.666667       28.000000  104.000000       29.0    10.440172
#
#    dataset_index
# 0            2.0
# 1            2.0
# 2            2.0
# 3            2.0

# %%
melt_rate_df = pd.melt(grouped_df, id_vars=['dataset_name', 'algo', 'dataset_index'], value_vars=['fdr', 'tpr', 'fpr'], value_name='rate', var_name='measurement')
melt_rate_df.head()
# Out:
#                dataset_name      algo  dataset_index measurement      rate
# 0                medium_all   dag_gnn            2.0         fdr  0.611111
# 1                medium_all  gran_dag            2.0         fdr  0.363095
# 2                medium_all    rl_bic            2.0         fdr  0.669553
# 3                medium_all       sam            2.0         fdr  0.715825
# 4  medium_no_issue_no_noise   dag_gnn            2.0         fdr  0.510256

# %%
melt_abs_err_df = pd.melt(grouped_df, id_vars=['dataset_name', 'algo', 'dataset_index'], value_vars=['shd', 'false_pos', 'false_neg', 'reserved_edges', 'pred_size', 'true_size'], value_name='value', var_name='measurement')
melt_abs_err_df.head()
# Out:
#                dataset_name      algo  dataset_index measurement      value
# 0                medium_all   dag_gnn            2.0         shd  29.666667
# 1                medium_all  gran_dag            2.0         shd  25.333333
# 2                medium_all    rl_bic            2.0         shd  30.333333
# 3                medium_all       sam            2.0         shd  60.333333
# 4  medium_no_issue_no_noise   dag_gnn            2.0         shd  29.000000

# %%
melt_time_df = pd.melt(grouped_df, id_vars=['dataset_name', 'algo', 'dataset_index'], value_vars=['timing'], value_name='seconds', var_name='measurement')
melt_time_df.head()
# Out:
#                dataset_name      algo  dataset_index measurement      seconds
# 0                medium_all   dag_gnn            2.0      timing  3886.790437
# 1                medium_all  gran_dag            2.0      timing     2.463730
# 2                medium_all    rl_bic            2.0      timing  7062.216417
# 3                medium_all       sam            2.0      timing    10.440172
# 4  medium_no_issue_no_noise   dag_gnn            2.0      timing  4506.590064

# %%
metrics_dfs = [melt_rate_df, melt_abs_err_df, melt_time_df]
dataset_names = list(melt_time_df['dataset_name'].unique())
len(dataset_names)
# Out:
# 3

# %%
dataset_names
# Out:
# ['medium_all', 'medium_no_issue_no_noise', 'medium_no_issue_noise']

# %%
for metrics in metrics_dfs:
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 6), sharey=True)
    sns.barplot(ax=ax1, y=list(metrics.columns)[-1], x='measurement',data=metrics[metrics['dataset_name'] == dataset_names[0]], hue='algo')
    sns.barplot(ax=ax2, y=list(metrics.columns)[-1], x='measurement',data=metrics[metrics['dataset_name'] == dataset_names[1]], hue='algo')
    sns.barplot(ax=ax3, y=list(metrics.columns)[-1], x='measurement',data=metrics[metrics['dataset_name'] == dataset_names[2]], hue='algo')
    ax1.tick_params(labelrotation=45)
    ax2.tick_params(labelrotation=45)
    ax3.tick_params(labelrotation=45)
    ax1.title.set_text(dataset_names[0])
    ax2.title.set_text(dataset_names[1])
    ax3.title.set_text(dataset_names[2])
    fig.suptitle(list(metrics.columns)[-1], fontsize=16)
    plt.show()
